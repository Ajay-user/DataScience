# %%
import random
import pickle
import pathlib

import nltk
from nltk.corpus import stopwords
from nltk.corpus import movie_reviews
from nltk.classify.scikitlearn import SklearnClassifier

from sklearn.naive_bayes import GaussianNB, MultinomialNB, ComplementNB, CategoricalNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier

from statistics import mode

# %% [markdown]
# ## Import Data

# %%
# lets create a  dataset using movie reviws data
documents = []
for category in movie_reviews.categories():
    for file in movie_reviews.fileids(category):
        review = movie_reviews.words(fileids=file)
        documents.append((review,category))
        
# total documents 
print('total documents in our dataset',len(documents))

# let's shuffle the data
random.seed(42)
random.shuffle(documents)

# lets check the first five doc + labels
documents[:5]
# Out:
# total documents in our dataset 2000
# [(['mr', '.', 'bean', ',', 'a', 'bumbling', 'security', ...], 'neg'),
#  (['when', 'casting', 'the', 'key', 'part', 'of', 'the', ...], 'pos'),
#  (['there', 'is', 'a', 'scene', 'in', 'patch', 'adams', ...], 'neg'),
#  (['and', 'i', 'thought', '"', 'stigmata', '"', 'would', ...], 'neg'),
#  (['some', 'critics', ',', 'including', 'siskel', '&', ...], 'pos')]

# %% [markdown]
# ## Vocab

# %%
vocab = movie_reviews.words()

# STOP WORDS
STOP_WORDS = stopwords.words('english')
print("STOP WORDS :",STOP_WORDS[:5])

# improve the vocab
vocab = [word for word in vocab if word not in STOP_WORDS]
print('length of vocab',len(vocab))
# Out:
# STOP WORDS : ['i', 'me', 'my', 'myself', 'we']
# length of vocab 955610

# %% [markdown]
# # Frequency distribution

# %%
freq = nltk.FreqDist(vocab)
# top most common words
top_500 = freq.most_common()[:500]
top_500 = [tup[0] for tup in top_500]

# %% [markdown]
# ## Feature Extraction

# %%
# %%time
features = []

for review, sentiment in documents:
    lookup = {word:True for word in review}
    mulit_hot_vector = {}
    for word in top_500:
        try:
            if lookup[word]:
                mulit_hot_vector[word]=True
        except:
            mulit_hot_vector[word]=False
    
    features.append((mulit_hot_vector,sentiment))
    

# Test driven development
assert len(documents) == len(features)
# Out:
# CPU times: total: 2.06 s
# Wall time: 2.05 s

# %% [markdown]
# ## Train Test split

# %%
train_set = features[:1900]
test_set = features[1900:]

# %% [markdown]
# ## NLTK Bayes classifier

# %%
bayes = nltk.NaiveBayesClassifier.train(train_set)
accuracy = nltk.classify.accuracy(bayes, test_set)
print('Model accuracy : ', accuracy)
# Out:
# Model accuracy :  0.71

# %% [markdown]
# ## Scikit Learn Classifiers
#
# * Bayes
#     * GaussianNB
#     * MultinomialNB
#     * ComplementNB
#     * CategoricalNB
#     * BernoulliNB
# * Linear models
#     * LogisticRegression
#     * SGDClassifier

# %% [markdown]
# ##  Gaussian Naive Bayes

# %%
gnb = SklearnClassifier(GaussianNB(),sparse=False)
# training
gnb.train(train_set)
# accuracy
accuracy = nltk.classify.accuracy(gnb, test_set)
print('Model accuracy : ', accuracy)
# Out:
# Model accuracy :  0.73

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
mnb = SklearnClassifier(MultinomialNB())
# training
mnb.train(train_set)
# accuracy
accuracy = nltk.classify.accuracy(mnb, test_set)
print('Model accuracy : ', accuracy)
# Out:
# Model accuracy :  0.68

# %% [markdown]
# ## Complement Naive Bayes

# %%
cnb = SklearnClassifier(ComplementNB())
# training
cnb.train(train_set)
# accuracy
accuracy = nltk.classify.accuracy(cnb, test_set)
print('Model accuracy : ', accuracy)
# Out:
# Model accuracy :  0.68

# %% [markdown]
# ## Bernoulli Naive Bayes

# %%
bnb = SklearnClassifier(BernoulliNB())
# training
bnb.train(train_set)
# accuracy
accuracy = nltk.classify.accuracy(bnb, test_set)
print('Model accuracy : ', accuracy)
# Out:
# Model accuracy :  0.71

# %% [markdown]
# ## Categorical Naive Bayes

# %%
catnb = SklearnClassifier(CategoricalNB(), sparse=False)
# training
catnb.train(train_set)
# accuracy
accuracy = nltk.classify.accuracy(catnb, test_set)
print('Model accuracy : ', accuracy)
# Out:
# Model accuracy :  0.71

# %% [markdown]
# ## Logistic Regression

# %%
lr = SklearnClassifier(LogisticRegression(max_iter=500))
# training
lr.train(train_set)
# accuracy
accuracy = nltk.classify.accuracy(lr, test_set)
print('Model accuracy : ', accuracy)
# Out:
# Model accuracy :  0.75

# %% [markdown]
# ## SGD Classifier

# %%
sgd = SklearnClassifier(SGDClassifier())
# training
sgd.train(train_set)
# accuracy
accuracy = nltk.classify.accuracy(sgd, test_set)
print('Model accuracy : ', accuracy)
# Out:
# Model accuracy :  0.73

# %% [markdown]
# ## Voting and Confidence

# %%
# collect predictions givens by different model

model_outputs = [] 

for model in [gnb, mnb, cnb, bnb, catnb, lr, sgd]:
    outputs = model.classify_many([tup[0] for tup in test_set])
    model_outputs.append(outputs)

# %%
# confidence calculation via voting

votes = []

for i, votes in enumerate(zip(*model_outputs)):
    print('Test set review :',i)
    print('Votes : ',votes)
    print('Majority : ',mode(votes))
    print('True label : ',test_set[i][1])
    print(f'Prediction confidence : {( votes.count(mode(votes)) / len(votes) )*100 :.1f}%',  )
    print('..'*40)
# Out:
# Test set review : 0
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 1
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 2
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 3
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 4
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  neg
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 5
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 6
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 85.7%
# ................................................................................
# Test set review : 7
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 8
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 9
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 10
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 11
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 12
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg')
# Majority :  pos
# True label :  pos
# Prediction confidence : 85.7%
# ................................................................................
# Test set review : 13
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 14
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 15
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  neg
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 16
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 17
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 18
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos')
# Majority :  neg
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 19
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 20
# Votes :  ('neg', 'pos', 'pos', 'neg', 'neg', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 57.1%
# ................................................................................
# Test set review : 21
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 22
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 23
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 24
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  neg
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 25
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 26
# Votes :  ('pos', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos')
# Majority :  neg
# True label :  pos
# Prediction confidence : 57.1%
# ................................................................................
# Test set review : 27
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 28
# Votes :  ('pos', 'pos', 'pos', 'neg', 'neg', 'pos', 'neg')
# Majority :  pos
# True label :  pos
# Prediction confidence : 57.1%
# ................................................................................
# Test set review : 29
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 30
# Votes :  ('neg', 'pos', 'pos', 'neg', 'neg', 'pos', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 57.1%
# ................................................................................
# Test set review : 31
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 32
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 33
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 34
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 35
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 36
# Votes :  ('pos', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  pos
# Prediction confidence : 57.1%
# ................................................................................
# Test set review : 37
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 38
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 39
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 85.7%
# ................................................................................
# Test set review : 40
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 41
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 42
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 43
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 44
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 45
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 46
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  neg
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 47
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 48
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 49
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 50
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 51
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 52
# Votes :  ('neg', 'pos', 'pos', 'neg', 'neg', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 57.1%
# ................................................................................
# Test set review : 53
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 54
# Votes :  ('pos', 'neg', 'neg', 'pos', 'pos', 'pos', 'neg')
# Majority :  pos
# True label :  pos
# Prediction confidence : 57.1%
# ................................................................................
# Test set review : 55
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  neg
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 56
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 57
# Votes :  ('pos', 'pos', 'pos', 'neg', 'neg', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 58
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 59
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 60
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 61
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 62
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 63
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'neg')
# Majority :  pos
# True label :  pos
# Prediction confidence : 85.7%
# ................................................................................
# Test set review : 64
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  neg
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 65
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 66
# Votes :  ('pos', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 85.7%
# ................................................................................
# Test set review : 67
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 68
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 69
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos')
# Majority :  neg
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 70
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 71
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 72
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 73
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 74
# Votes :  ('neg', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  pos
# Prediction confidence : 57.1%
# ................................................................................
# Test set review : 75
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 76
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 77
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos')
# Majority :  neg
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 78
# Votes :  ('neg', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 79
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 80
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 81
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 82
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 83
# Votes :  ('pos', 'neg', 'neg', 'pos', 'pos', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 57.1%
# ................................................................................
# Test set review : 84
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 85
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 86
# Votes :  ('pos', 'neg', 'neg', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 87
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 88
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos')
# Majority :  neg
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 89
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'neg', 'neg')
# Majority :  pos
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 90
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 91
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 92
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 93
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 94
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 100.0%
# ................................................................................
# Test set review : 95
# Votes :  ('neg', 'pos', 'pos', 'neg', 'neg', 'neg', 'neg')
# Majority :  neg
# True label :  neg
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 96
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos')
# Majority :  neg
# True label :  pos
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 97
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'neg', 'pos')
# Majority :  neg
# True label :  neg
# Prediction confidence : 85.7%
# ................................................................................
# Test set review : 98
# Votes :  ('neg', 'neg', 'neg', 'neg', 'neg', 'pos', 'pos')
# Majority :  neg
# True label :  neg
# Prediction confidence : 71.4%
# ................................................................................
# Test set review : 99
# Votes :  ('pos', 'pos', 'pos', 'pos', 'pos', 'pos', 'pos')
# Majority :  pos
# True label :  pos
# Prediction confidence : 100.0%
# ................................................................................
